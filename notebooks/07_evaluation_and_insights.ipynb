# %% [markdown]
# # Notebook 07: Evaluation & Business Insights
#
# Rolling backtesting, segment decomposition, and business narrative.

# %%
import pandas as pd
from src.evaluation.backtesting import BacktestConfig, summarize_backtest
from src.evaluation.metrics import evaluate_by_segment
from src.config.config import DATA_PROCESSED_DIR, PRIMARY_TARGET

# %% [markdown]
# ## Evaluation Design
# - Rolling-origin backtesting: 4 folds, 13-week horizon per fold
# - Metrics: MAE, RMSE, MAPE, sMAPE, WAPE, Bias
# - Segment evaluation: by retailer, object, category
#
# ## Business Insights Framework
# - Top growing/declining retailers
# - Most seasonal and most volatile objects
# - Strongest forecast confidence segments
# - Anomaly periods
