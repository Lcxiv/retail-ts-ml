# %% [markdown]
# # Notebook 02: Mock Data Generation
#
# Generates synthetic retail sales data using `src/data/mock_generator.py`.
# The dataset simulates 4 retailers, 6 selling objects, and ~4 years of weekly history.

# %%
import pandas as pd
import matplotlib.pyplot as plt
from src.data.mock_generator import generate_synthetic_data
from src.utils.helpers import summarize_df

# %%
df = generate_synthetic_data(save=True)
df.head()

# %%
summarize_df(df)

# %%
from src.visualization.plots import plot_sales_trend
fig = plot_sales_trend(df)
fig.show()

# %%
from src.visualization.plots import plot_seasonality_heatmap
fig = plot_seasonality_heatmap(df)
fig.show()

# %% [markdown]
# ## Observations
# Record your observations about the synthetic data here.
