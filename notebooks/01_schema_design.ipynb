# %% [markdown]
# # Notebook 01: Schema Design
#
# This notebook documents the column roles and schema design.
# Update `src/data/schema.py` with real columns once the final dataset is provided.

# %%
from src.data.schema import SCHEMA
from src.config.config import RETAILER_PROFILES, OBJECT_PROFILES
import pandas as pd

# %%
print('Entity keys:', SCHEMA.entity_keys())
print('Hierarchy fields:', SCHEMA.hierarchy_fields())
print('Driver features:', SCHEMA.driver_features())
print('Event features:', SCHEMA.event_features())
print('Primary target:', SCHEMA.primary_target)

# %% [markdown]
# ## Open Questions
# When real columns arrive, answer:
# - Exact date column name?
# - Primary target variable?
# - Time grain (daily/weekly/monthly)?
# - Forecast horizon?
# - Hierarchy depth?
