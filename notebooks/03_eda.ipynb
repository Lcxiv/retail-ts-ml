# %% [markdown]
# # Notebook 03: Exploratory Data Analysis
#
# Time series EDA: completeness, distributions, trends, seasonality, volatility.

# %%
import pandas as pd
import plotly.express as px
from src.utils.helpers import summarize_df, fill_missing_dates
from src.visualization.plots import plot_sales_trend, plot_rolling_average_comparison, plot_seasonality_heatmap

# %%
from src.config.config import DATA_SYNTHETIC_DIR
df = pd.read_parquet(DATA_SYNTHETIC_DIR / 'synthetic_retail_sales.parquet')
df.shape

# %%
summarize_df(df)

# %%
plot_sales_trend(df, color_col='retailer_id', title='Total Units Sold by Retailer').show()

# %%
plot_rolling_average_comparison(df, window=8).show()

# %%
plot_seasonality_heatmap(df).show()
